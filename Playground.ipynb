# %%
import numpy as np
import matplotlib.pyplot as plt


data = np.genfromtxt('./data/highway_map.csv', delimiter=' ')

# %%
data[0:3]
# Out:
# array([[  7.84600100e+02,   1.13557100e+03,   0.00000000e+00,
#          -2.35983100e-02,  -9.99721600e-01],
#        [  8.15267900e+02,   1.13493000e+03,   3.06744785e+01,
#          -1.09947900e-02,  -9.99939600e-01],
#        [  8.44639800e+02,   1.13491100e+03,   6.00463715e+01,
#          -2.04837300e-03,  -9.99997900e-01]])

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.set_title("Track")    
ax1.plot(data[:,0],data[:,1])

plt.show()
